# %%
import xetrapal, pandas,json, numpy
from xetrapal import gdastras
a=xetrapal.karma.load_xpal_smriti("/opt/xpal-data//avxpal.json")
avxpal=xetrapal.Xetrapal(a)
config=xetrapal.karma.load_config_json(a.configfile)
pygsheetsconfig = xetrapal.karma.load_config_json(config['Pygsheets']['avdrive'])
gd = gdastras.gd_get_googledriver(pygsheetsconfig)
# Out:
# 2020-08-10 18:10:29 Xpal-Sutradhar-MainThread-[load_xpal_smriti] INFO : Loaded config from /opt/xpal-data//avxpal.json
# 2020-08-10 18:10:29 Dwarkanath-MainThread-[__init__] INFO : My name is Dwarkanath
# 2020-08-10 18:10:29 Dwarkanath-MainThread-[setup_disk] INFO : I already have a datapath at the location /opt/xpal-data/xetrapal-data
# 2020-08-10 18:10:29 Dwarkanath-MainThread-[start_session] INFO : Creating a new path for this session at /opt/xpal-data/xetrapal-data/Dwarkanath-2020Aug10-181029
# 2020-08-10 18:10:29 Dwarkanath-MainThread-[start_session] INFO : Creating a new download path for this session at /opt/xpal-data/xetrapal-data/Dwarkanath-2020Aug10-181029/downloads
# 2020-08-10 18:10:29 Dwarkanath-MainThread-[start_session] INFO : Creating a new json path for this session at /opt/xpal-data/xetrapal-data/Dwarkanath-2020Aug10-181029/json
# 2020-08-10 18:10:29 Dwarkanath-MainThread-[log_to_disk] INFO : Saving messages to log at /opt/xpal-data/xetrapal-data/Dwarkanath-2020Aug10-181029/jeevasession.log
# 2020-08-10 18:10:29 Dwarkanath-MainThread-[dhaarana] INFO : Trying to load module xetrapal.astra
# 2020-08-10 18:10:29 Dwarkanath-MainThread-[dhaarana] INFO : I now have functions ['get_browser', 'get_headless_browser', 'get_xpal_logger']
# 2020-08-10 18:10:29 Dwarkanath-MainThread-[dhaarana] INFO : Trying to load module xetrapal.karma
# 2020-08-10 18:10:29 Dwarkanath-MainThread-[dhaarana] INFO : I now have functions ['close_modal', 'copy_smriti', 'deepcopy', 'download_file', 'export_table', 'get_aadesh', 'get_browser', 'get_color_json', 'get_formatted_json', 'get_headless_browser', 'get_remote_smriti_status', 'get_smriti_status', 'get_xpal_logger', 'load_config', 'load_config_json', 'load_xpal_smriti', 'pull_smritis', 'save_config', 'save_data_to_jsonfile', 'scroll_page', 'scroll_to_bottom', 'scroll_up', 'urlopen', 'uuid4', 'wait']
# 2020-08-10 18:10:29 Dwarkanath-MainThread-[update_astras] INFO : Trying to update astras
# 2020-08-10 18:10:29 Dwarkanath-MainThread-[update_astras] WARNING : I dont seem to have any astras
# 2020-08-10 18:10:29 Dwarkanath-MainThread-[update_vaahans] INFO : Trying to update vaahans
# 2020-08-10 18:10:29 Dwarkanath-MainThread-[update_vaahans] WARNING : I dont seem to have any vaahans
# 2020-08-10 18:10:29 Xpal-Sutradhar-MainThread-[gd_get_googledriver] INFO : Trying to log into Google drive

# %%
iodgraph = gd.open("The Internet of DevSec")
ddsheet=gd.open("Domestic Digital Partner Potentials")

#rels=ndhmgraph.work

# %%
edgesheet=iodgraph.worksheet_by_title("edges")
nodesheet=iodgraph.worksheet_by_title("nodes")
omidyarsheet=ddsheet.worksheet_by_title("Omidyar Partners")

# %%
edges = edgesheet.get_as_df(include_tailing_empty=False)
edges
# nodes = nodesheet.get_as_df(include_tailing_empty=False).dropna()
# Out:
#                           source                        story  \
# 0                       Abhishek               is a member of
# 1                       Abhishek           was a resident at
# 2                  Adith Haridas               is a member of
# 3                Aditya Dipankar                     attended
# 4                Aditya Dipankar               is a member of
# 5                    Akash Upase                     attended
# 6                    Akash Upase               is a member of
# 7                 Arandeep Singh                     attended
# 8                 Arandeep Singh               is a member of
# 9              Arjun Venkatraman                 co-developed
# 10             Arjun Venkatraman                 co-developed
# 11             Arjun Venkatraman                   co-founded
# 12             Arjun Venkatraman                  facilitated
# 13             Arjun Venkatraman               is a fellow at
# 14             Arjun Venkatraman             is a partner in
# 15             Arjun Venkatraman                     manages
# 16             Arjun Venkatraman                     works at
# 17                  Ashima Joshi  is a Young Leader Fellow at
# 18                Ashish Birulee                     attended
# 19                Ashish Birulee               is a member of
# 20                    Bamshankar                     attended
# 21                    Bamshankar               is a member of
# 22                          BMGF                        funds
# 23                          BMGF                        funds
# 24                          BMGF                        funds
# 25                          BMGF                   has funded
# 26                           CIS    funded the development of
# 27                       CIVICUS      is a founding member of
# 28                   Counterpart            was a partner of
# 29                      Data.org                 is funded by
# ..                           ...                          ...
# 418              Ramji Raghavan            is a key person at
# 419           Ramya Venkataraman               is a fellow at
# 420           Ramya Venkataraman           is a key person at
# 421    Rao Padmanabha Yerravalli               is a fellow at
# 422    Rao Padmanabha Yerravalli           is a key person at
# 423            Raveendran Kannan               is a fellow at
# 424             Ravichandra Raju               is a fellow at
# 425             Ravichandra Raju           is a key person at
# 426                 Renu Appachu               is a fellow at
# 427                 Renu Appachu           is a key person at
# 428        Romulus Earl Whitaker               is a fellow at
# 429        Romulus Earl Whitaker           is a key person at
# 430                  S.L.N Swamy               is a fellow at
# 431                  S.L.N Swamy           is a key person at
# 432        Sagari Radhika Ramdas               is a fellow at
# 433      Sameer Subhash Sawarkar               is a fellow at
# 434      Sameer Subhash Sawarkar           is a key person at
# 435                   Sampath JM               is a fellow at
# 436                   Sampath JM           is a key person at
# 437                           33               is a fellow at
# 438                           33           is a key person at
# 439  Santhanagopalan Rajagopalan               is a fellow at
# 440  Santhanagopalan Rajagopalan           is a key person at
# 441         Sarat Babu Vasireddy               is a fellow at
# 442         Sarat Babu Vasireddy           is a key person at
# 443              Shanti Raghavan               is a fellow at
# 444              Shanti Raghavan           is a key person at
# 445             Shivaram Pailoor               is a fellow at
# 446             Shivaram Pailoor           is a key person at
# 447                  Shree Padre               is a fellow at
#
#                                                 target  weight
# 0                                           Hackergram       1
# 1                                           Hackergram       1
# 2                                           Hackergram       1
# 3                       Hackergram Innovation Lab 2019       1
# 4                                           Hackergram       1
# 5                       Hackergram Innovation Lab 2019       1
# 6                                           Hackergram       1
# 7                       Hackergram Innovation Lab 2019       1
# 8                                           Hackergram       1
# 9                                            TrollBait       1
# 10                                            Xetrapal       1
# 11                                          Hackergram       1
# 12                      Hackergram Innovation Lab 2019       1
# 13                                              Ashoka       1
# 14                                    TechZone Academy       1
# 15                              The Mojolab Foundation       1
# 16                                                BMGF       1
# 17                              The Mojolab Foundation       1
# 18                      Hackergram Innovation Lab 2019       1
# 19                                          Hackergram       1
# 20                      Hackergram Innovation Lab 2019       1
# 21                                          Hackergram       1
# 22                                        AccessHealth       1
# 23                                                CDFI       1
# 24                                      Onion Dev Tech       1
# 25                                  Samagra Sanitation       1
# 26                                           TrollBait       1
# 27                               Innovation For Change       1
# 28                               Innovation For Change       1
# 29                              Rockefeller Foundation       1
# ..                                                 ...     ...
# 418                   Agastya International foundation       1
# 419                                             Ashoka       1
# 420                   Center For Teacher Accreditation       1
# 421                                             Ashoka       1
# 422  Rishi Valley Institute for Educational Resourc...       1
# 423                                             Ashoka       1
# 424                                             Ashoka       1
# 425                                  Bhavishya Bharthi       1
# 426                                             Ashoka       1
# 427                                           Jagruiti       1
# 428                                             Ashoka       1
# 429                 Agumbe Rainforest Research Station       1
# 430                                             Ashoka       1
# 431                                    The Adventurers       1
# 432                                             Ashoka       1
# 433                                             Ashoka       1
# 434               Neurosynaptic Communications Pvt Ltd       1
# 435                                             Ashoka       1
# 436                       Arpitha  Associates Pvt. Ltd       1
# 437                                             Ashoka       1
# 438                                   Amar Seva Sangam       1
# 439                                             Ashoka       1
# 440            Technology Informatics Design Endeavour       1
# 441                                             Ashoka       1
# 442                                        Pratyamanya       1
# 443                                             Ashoka       1
# 444                                       Enable India       1
# 445                                             Ashoka       1
# 446   CAAM ( Centre for Alternative Agricultur Media )       1
# 447                                             Ashoka       1
#
# [448 rows x 4 columns]

# %%
edges
# Out:
#                           source                        story  \
# 0                       Abhishek               is a member of
# 1                       Abhishek           was a resident at
# 2                  Adith Haridas               is a member of
# 3                Aditya Dipankar                     attended
# 4                Aditya Dipankar               is a member of
# 5                    Akash Upase                     attended
# 6                    Akash Upase               is a member of
# 7                 Arandeep Singh                     attended
# 8                 Arandeep Singh               is a member of
# 9              Arjun Venkatraman                 co-developed
# 10             Arjun Venkatraman                 co-developed
# 11             Arjun Venkatraman                   co-founded
# 12             Arjun Venkatraman                  facilitated
# 13             Arjun Venkatraman               is a fellow at
# 14             Arjun Venkatraman             is a partner in
# 15             Arjun Venkatraman                     manages
# 16             Arjun Venkatraman                     works at
# 17                  Ashima Joshi  is a Young Leader Fellow at
# 18                Ashish Birulee                     attended
# 19                Ashish Birulee               is a member of
# 20                    Bamshankar                     attended
# 21                    Bamshankar               is a member of
# 22                          BMGF                        funds
# 23                          BMGF                        funds
# 24                          BMGF                        funds
# 25                          BMGF                   has funded
# 26                           CIS    funded the development of
# 27                       CIVICUS      is a founding member of
# 28                   Counterpart            was a partner of
# 29                      Data.org                 is funded by
# ..                           ...                          ...
# 418              Ramji Raghavan            is a key person at
# 419           Ramya Venkataraman               is a fellow at
# 420           Ramya Venkataraman           is a key person at
# 421    Rao Padmanabha Yerravalli               is a fellow at
# 422    Rao Padmanabha Yerravalli           is a key person at
# 423            Raveendran Kannan               is a fellow at
# 424             Ravichandra Raju               is a fellow at
# 425             Ravichandra Raju           is a key person at
# 426                 Renu Appachu               is a fellow at
# 427                 Renu Appachu           is a key person at
# 428        Romulus Earl Whitaker               is a fellow at
# 429        Romulus Earl Whitaker           is a key person at
# 430                  S.L.N Swamy               is a fellow at
# 431                  S.L.N Swamy           is a key person at
# 432        Sagari Radhika Ramdas               is a fellow at
# 433      Sameer Subhash Sawarkar               is a fellow at
# 434      Sameer Subhash Sawarkar           is a key person at
# 435                   Sampath JM               is a fellow at
# 436                   Sampath JM           is a key person at
# 437                           33               is a fellow at
# 438                           33           is a key person at
# 439  Santhanagopalan Rajagopalan               is a fellow at
# 440  Santhanagopalan Rajagopalan           is a key person at
# 441         Sarat Babu Vasireddy               is a fellow at
# 442         Sarat Babu Vasireddy           is a key person at
# 443              Shanti Raghavan               is a fellow at
# 444              Shanti Raghavan           is a key person at
# 445             Shivaram Pailoor               is a fellow at
# 446             Shivaram Pailoor           is a key person at
# 447                  Shree Padre               is a fellow at
#
#                                                 target  weight
# 0                                           Hackergram       1
# 1                                           Hackergram       1
# 2                                           Hackergram       1
# 3                       Hackergram Innovation Lab 2019       1
# 4                                           Hackergram       1
# 5                       Hackergram Innovation Lab 2019       1
# 6                                           Hackergram       1
# 7                       Hackergram Innovation Lab 2019       1
# 8                                           Hackergram       1
# 9                                            TrollBait       1
# 10                                            Xetrapal       1
# 11                                          Hackergram       1
# 12                      Hackergram Innovation Lab 2019       1
# 13                                              Ashoka       1
# 14                                    TechZone Academy       1
# 15                              The Mojolab Foundation       1
# 16                                                BMGF       1
# 17                              The Mojolab Foundation       1
# 18                      Hackergram Innovation Lab 2019       1
# 19                                          Hackergram       1
# 20                      Hackergram Innovation Lab 2019       1
# 21                                          Hackergram       1
# 22                                        AccessHealth       1
# 23                                                CDFI       1
# 24                                      Onion Dev Tech       1
# 25                                  Samagra Sanitation       1
# 26                                           TrollBait       1
# 27                               Innovation For Change       1
# 28                               Innovation For Change       1
# 29                              Rockefeller Foundation       1
# ..                                                 ...     ...
# 418                   Agastya International foundation       1
# 419                                             Ashoka       1
# 420                   Center For Teacher Accreditation       1
# 421                                             Ashoka       1
# 422  Rishi Valley Institute for Educational Resourc...       1
# 423                                             Ashoka       1
# 424                                             Ashoka       1
# 425                                  Bhavishya Bharthi       1
# 426                                             Ashoka       1
# 427                                           Jagruiti       1
# 428                                             Ashoka       1
# 429                 Agumbe Rainforest Research Station       1
# 430                                             Ashoka       1
# 431                                    The Adventurers       1
# 432                                             Ashoka       1
# 433                                             Ashoka       1
# 434               Neurosynaptic Communications Pvt Ltd       1
# 435                                             Ashoka       1
# 436                       Arpitha  Associates Pvt. Ltd       1
# 437                                             Ashoka       1
# 438                                   Amar Seva Sangam       1
# 439                                             Ashoka       1
# 440            Technology Informatics Design Endeavour       1
# 441                                             Ashoka       1
# 442                                        Pratyamanya       1
# 443                                             Ashoka       1
# 444                                       Enable India       1
# 445                                             Ashoka       1
# 446   CAAM ( Centre for Alternative Agricultur Media )       1
# 447                                             Ashoka       1
#
# [448 rows x 4 columns]

# %%
links=edges.to_dict(orient="records")
links
# Out:
# [{'source': 'Abhishek',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Abhishek',
#   'story': 'was a resident at ',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Adith Haridas',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Aditya Dipankar',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Aditya Dipankar',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Akash Upase',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Akash Upase',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Arandeep Singh',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Arandeep Singh',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Arjun Venkatraman',
#   'story': 'co-developed',
#   'target': 'TrollBait',
#   'weight': 1},
#  {'source': 'Arjun Venkatraman',
#   'story': 'co-developed',
#   'target': 'Xetrapal',
#   'weight': 1},
#  {'source': 'Arjun Venkatraman',
#   'story': 'co-founded',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Arjun Venkatraman',
#   'story': 'facilitated',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Arjun Venkatraman',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Arjun Venkatraman',
#   'story': 'is a partner in ',
#   'target': 'TechZone Academy',
#   'weight': 1},
#  {'source': 'Arjun Venkatraman',
#   'story': 'manages ',
#   'target': 'The Mojolab Foundation',
#   'weight': 1},
#  {'source': 'Arjun Venkatraman',
#   'story': 'works at',
#   'target': 'BMGF',
#   'weight': 1},
#  {'source': 'Ashima Joshi',
#   'story': 'is a Young Leader Fellow at',
#   'target': 'The Mojolab Foundation',
#   'weight': 1},
#  {'source': 'Ashish Birulee',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Ashish Birulee',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Bamshankar',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Bamshankar',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'BMGF', 'story': 'funds', 'target': 'AccessHealth', 'weight': 1},
#  {'source': 'BMGF', 'story': 'funds', 'target': 'CDFI', 'weight': 1},
#  {'source': 'BMGF', 'story': 'funds', 'target': 'Onion Dev Tech', 'weight': 1},
#  {'source': 'BMGF',
#   'story': 'has funded',
#   'target': 'Samagra Sanitation',
#   'weight': 1},
#  {'source': 'CIS',
#   'story': 'funded the development of',
#   'target': 'TrollBait',
#   'weight': 1},
#  {'source': 'CIVICUS',
#   'story': 'is a founding member of',
#   'target': 'Innovation For Change',
#   'weight': 1},
#  {'source': 'Counterpart',
#   'story': 'was a partner of ',
#   'target': 'Innovation For Change',
#   'weight': 1},
#  {'source': 'Data.org',
#   'story': 'is funded by',
#   'target': 'Rockefeller Foundation',
#   'weight': 1},
#  {'source': 'Data.org',
#   'story': 'is interested in',
#   'target': 'Voice CoP',
#   'weight': 1},
#  {'source': 'Deepta Naha',
#   'story': 'co-founded',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Deepta Naha',
#   'story': 'contributed to',
#   'target': 'TrollBait',
#   'weight': 1},
#  {'source': 'Deepta Naha',
#   'story': 'facilitated',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Deepta Naha',
#   'story': 'is the innovations coordinator of',
#   'target': 'I4C SA Hub',
#   'weight': 1},
#  {'source': 'Deepta Naha',
#   'story': 'started',
#   'target': 'Bong Book Cafe',
#   'weight': 1},
#  {'source': 'Diana Arce',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Environics Trust',
#   'story': 'is a founding member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Environics Trust',
#   'story': 'is an incubating partner of ',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Environics Trust',
#   'story': 'is the fiscal partner to',
#   'target': 'Tides',
#   'weight': 1},
#  {'source': 'Environics Trust',
#   'story': 'submitted a proposal to',
#   'target': 'Data.org',
#   'weight': 1},
#  {'source': 'Gaurav',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Hackergram',
#   'story': 'incubates',
#   'target': 'Bong Book Cafe',
#   'weight': 1},
#  {'source': 'Hackergram',
#   'story': 'incubates',
#   'target': 'TechZone Academy',
#   'weight': 1},
#  {'source': 'Hackergram',
#   'story': 'is an incubator for',
#   'target': 'I4C SA Hub',
#   'weight': 1},
#  {'source': 'Hackergram',
#   'story': 'is incubating',
#   'target': 'Programming Wagera Wagera ',
#   'weight': 1},
#  {'source': 'Hackergram',
#   'story': 'is incubating',
#   'target': 'TechZone Academy',
#   'weight': 1},
#  {'source': 'Hackergram',
#   'story': 'joined',
#   'target': 'Innovation For Change',
#   'weight': 1},
#  {'source': 'Hackergram',
#   'story': 'organized',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Hackergram',
#   'story': 'submitted a proposal to',
#   'target': 'Data.org',
#   'weight': 1},
#  {'source': 'I4C SA Hub',
#   'story': 'is a part of',
#   'target': 'Innovation For Change',
#   'weight': 1},
#  {'source': 'IIT Mumbai',
#   'story': 'is working on ',
#   'target': 'Spoken Tutorials',
#   'weight': 1},
#  {'source': 'Innovation For Change',
#   'story': 'sponsored',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Kalapana Gururani',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Karan Joshi',
#   'story': 'apprenticed with',
#   'target': 'Arjun Venkatraman',
#   'weight': 1},
#  {'source': 'Karan Joshi',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Karan Joshi',
#   'story': 'co-developed',
#   'target': 'TrollBait',
#   'weight': 1},
#  {'source': 'Karan Joshi',
#   'story': 'co-developed',
#   'target': 'Xetrapal',
#   'weight': 1},
#  {'source': 'Karan Joshi',
#   'story': 'is a member of ',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Karan Joshi',
#   'story': 'was a resident at ',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Kavita Anand',
#   'story': 'founded',
#   'target': 'Adhyayan Foundation',
#   'weight': 1},
#  {'source': 'Kavita Anand',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Mohammad Saqib Shah',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Mohammad Saqib Shah',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Mohit Gupta',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Mohit Gupta',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Naalphad',
#   'story': 'is a brand associated with',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Naalphad',
#   'story': 'operates',
#   'target': 'Naalphad Open Mics',
#   'weight': 1},
#  {'source': 'Nirvikalpa',
#   'story': 'co-founded',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Data.org', 'weight': 1},
#  {'source': 'Omidyar',
#   'story': 'funds',
#   'target': 'DVARA Research',
#   'weight': 1},
#  {'source': 'Omidyar',
#   'story': 'funds',
#   'target': 'Bharat Inclusion Initiative',
#   'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'ISB', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'MOSIP', 'weight': 1},
#  {'source': 'Omidyar',
#   'story': 'funds',
#   'target': 'Centre for Social and Behaviour Change',
#   'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': '1MG', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Dailyhunt', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Goodera', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Healofy', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Health Kart', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'i2e1', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'imerit', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Indus', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Myupchar', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Now Floats', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Pratilipi', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Quikr', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Railyatri', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'u2opia', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Vyng', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'ZipGo', 'weight': 1},
#  {'source': 'Omidyar',
#   'story': 'funds',
#   'target': 'Aspiring Minds',
#   'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Bridge', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Centa', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Doubtnut', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Varthana', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Zest', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Shubh Loans', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Dealshare', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Bijak', 'weight': 1},
#  {'source': 'Omidyar',
#   'story': 'funds',
#   'target': 'Axio Biosolutions',
#   'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'CredR', 'weight': 1},
#  {'source': 'Omidyar',
#   'story': 'funds',
#   'target': 'Akshara Foundation',
#   'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Anudip', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'CAF', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Dream Dream', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'IDFC', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'MicroSave', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Vedantu', 'weight': 1},
#  {'source': 'Omidyar',
#   'story': 'funds',
#   'target': 'White Hat Jr',
#   'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Pratham', 'weight': 1},
#  {'source': 'Omidyar',
#   'story': 'funds',
#   'target': 'Teach For India',
#   'weight': 1},
#  {'source': 'Omidyar',
#   'story': 'funds',
#   'target': 'The Education Alliance',
#   'weight': 1},
#  {'source': 'Omidyar',
#   'story': 'funds',
#   'target': 'Village Capital: EdTech Accelerator',
#   'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Villgro', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'ADR', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'AffordPlan', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Ashoka', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'CBGA', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'CDFI', 'weight': 1},
#  {'source': 'Omidyar', 'story': 'funds', 'target': 'Dasra', 'weight': 1},
#  {'source': 'Praveer Peter',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Praveer Peter',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Prerna',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Prerna',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Programming Wagera Wagera ',
#   'story': 'is a CoP started by',
#   'target': 'Karan Joshi',
#   'weight': 1},
#  {'source': 'Ravi Jaiswal',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Ravi Jaiswal',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Rishabh ',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Sagolsem Pavel Meitei ',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Sagolsem Pavel Meitei ',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Sairam Natarajan',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Sairam Natarajan',
#   'story': 'is a trustee of ',
#   'target': 'The Mojolab Foundation',
#   'weight': 1},
#  {'source': 'Samagra Sanitation',
#   'story': 'was founded by',
#   'target': 'Swapnil Chaturvedi',
#   'weight': 1},
#  {'source': 'Sarbani Banerjee',
#   'story': 'works on ',
#   'target': 'Spoken Tutorials',
#   'weight': 1},
#  {'source': 'shirish',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'shirish',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Shivam Shumsher',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Spoken Tutorials',
#   'story': 'can leverage',
#   'target': 'Voice CoP',
#   'weight': 1},
#  {'source': 'Sreedhar Ramamurthi',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Sreedhar Ramamurthi',
#   'story': 'is a co-founder of ',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Sreedhar Ramamurthi',
#   'story': 'is a trustee of ',
#   'target': 'The Mojolab Foundation',
#   'weight': 1},
#  {'source': 'Suryaveer Gaur ',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Suryaveer Gaur ',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Suryaveer Gaur ',
#   'story': 'was a resident at ',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Swapnil Chaturvedi',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Talk2Geeks',
#   'story': 'provides tech support to',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Tania ',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Tania ',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'TechZone Academy',
#   'story': 'operates',
#   'target': 'Talk2Geeks',
#   'weight': 1},
#  {'source': 'The Mojolab Foundation',
#   'story': 'is an incubating partner of ',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Tides', 'story': 'funds', 'target': 'I4C SA Hub', 'weight': 1},
#  {'source': 'Tides',
#   'story': 'funds',
#   'target': 'Innovation For Change',
#   'weight': 1},
#  {'source': 'Trina Talukdar',
#   'story': 'is a founder of',
#   'target': 'Kranti',
#   'weight': 1},
#  {'source': 'Trina Talukdar',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Trina Talukdar',
#   'story': 'started',
#   'target': 'Bolti Band',
#   'weight': 1},
#  {'source': 'Trina Talukdar',
#   'story': 'used to work at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'USAID', 'story': 'funded', 'target': 'CIVICUS', 'weight': 1},
#  {'source': 'USAID', 'story': 'funded', 'target': 'Tides', 'weight': 1},
#  {'source': 'Utkarsh Jani ',
#   'story': 'is a member of',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Vinay Taragi',
#   'story': 'attended',
#   'target': 'Hackergram Innovation Lab 2019',
#   'weight': 1},
#  {'source': 'Vinay Taragi',
#   'story': 'founded',
#   'target': 'TechZone Academy',
#   'weight': 1},
#  {'source': 'Vinay Taragi',
#   'story': 'is a co-founder of ',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Vinay Taragi',
#   'story': 'is a Young Leader Fellow at',
#   'target': 'The Mojolab Foundation',
#   'weight': 1},
#  {'source': 'Voice CoP',
#   'story': 'is a community of practice started by',
#   'target': 'Hackergram',
#   'weight': 1},
#  {'source': 'Deepjyoti Sonu',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Deepjyoti Sonu',
#   'story': 'is a key person at',
#   'target': 'Farm2Food',
#   'weight': 1},
#  {'source': 'Emami Murmu',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Emami Murmu',
#   'story': 'is a key person at',
#   'target': 'Pragatisheel Mahila Sabha',
#   'weight': 1},
#  {'source': 'Sneh Kumar',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Sneh Kumar',
#   'story': 'is a key person at',
#   'target': 'ADITI',
#   'weight': 1},
#  {'source': 'Yambem Laba',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Yambem Laba',
#   'story': 'is a key person at',
#   'target': 'Manipur Mountaineering and Trekking Association',
#   'weight': 1},
#  {'source': 'Hasina Kharbhih',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Hasina Kharbhih',
#   'story': 'is a key person at',
#   'target': 'Impulse Social Enterprises',
#   'weight': 1},
#  {'source': 'Krishna Chandra Mishra ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Krishna Chandra Mishra ',
#   'story': 'is a key person at',
#   'target': 'E-Kutir',
#   'weight': 1},
#  {'source': 'Dilip Banerjee ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Dilip Banerjee ',
#   'story': 'is a key person at',
#   'target': 'Individual Dilip Banerjee',
#   'weight': 1},
#  {'source': 'Sarbani Das Roy ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Sarbani Das Roy ',
#   'story': 'is a key person at',
#   'target': 'Iswar Sankalpa',
#   'weight': 1},
#  {'source': 'Sikha Roy',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Sikha Roy',
#   'story': 'is a key person at',
#   'target': 'Srreoshi',
#   'weight': 1},
#  {'source': 'Sujay Santra ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Sujay Santra ',
#   'story': 'is a key person at',
#   'target': 'iKure Techsoft (P) Ltd',
#   'weight': 1},
#  {'source': 'KA Thomas ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'KA Thomas ',
#   'story': 'is a key person at',
#   'target': 'Institution for Culture And Rural Development (I-CARD)',
#   'weight': 1},
#  {'source': 'Pranjal Baruah',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Pranjal Baruah',
#   'story': 'is a key person at',
#   'target': 'Mushroom Development Foundation',
#   'weight': 1},
#  {'source': 'Ravindranath',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Ravindranath',
#   'story': 'is a key person at',
#   'target': 'River Basin Friends',
#   'weight': 1},
#  {'source': 'Soumyadeep Datta',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Soumyadeep Datta',
#   'story': 'is a key person at',
#   'target': "Nature's Beckon",
#   'weight': 1},
#  {'source': 'Kaushlendra Kumar',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Kaushlendra Kumar',
#   'story': 'is a key person at',
#   'target': 'Kaushalya Foundation',
#   'weight': 1},
#  {'source': 'Shashank Kumar',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Shashank Kumar',
#   'story': 'is a key person at',
#   'target': 'Farms and Farmers (FnF) Foundation',
#   'weight': 1},
#  {'source': 'Prasanta Tripathy',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Prasanta Tripathy',
#   'story': 'is a key person at',
#   'target': 'Ekjut',
#   'weight': 1},
#  {'source': 'Babloo Loitongbam ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Babloo Loitongbam ',
#   'story': 'is a key person at',
#   'target': 'Human Rights Alert',
#   'weight': 1},
#  {'source': 'Dr Bibhu Kalyan Mohanty',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Dr Bibhu Kalyan Mohanty',
#   'story': 'is a key person at',
#   'target': 'Sambandh',
#   'weight': 1},
#  {'source': 'Jagadish Pradhan ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Jagadish Pradhan ',
#   'story': 'is a key person at',
#   'target': 'Sahabhagi Vikas Abhiyan',
#   'weight': 1},
#  {'source': 'Sundara Narayana Patro',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Sundara Narayana Patro',
#   'story': 'is a key person at',
#   'target': 'Odisha Environmental Society',
#   'weight': 1},
#  {'source': 'Aditya Patnaik',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Aditya Patnaik',
#   'story': 'is a key person at',
#   'target': 'Antyodaya Chetna Mandal',
#   'weight': 1},
#  {'source': 'Abhijit Bardhan ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Abhijit Bardhan ',
#   'story': 'is a key person at',
#   'target': 'Science Communicators Forum',
#   'weight': 1},
#  {'source': 'Amlan Kusum Ganguly ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Amlan Kusum Ganguly ',
#   'story': 'is a key person at',
#   'target': 'Prayasam',
#   'weight': 1},
#  {'source': 'Anindita Majumdar',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Anindita Majumdar',
#   'story': 'is a key person at',
#   'target': 'EquiDiversity Foundation',
#   'weight': 1},
#  {'source': 'Anuradha Kapoor ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Anuradha Kapoor ',
#   'story': 'is a key person at',
#   'target': 'Swayam',
#   'weight': 1},
#  {'source': 'Aparna Banerjee',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Aparna Banerjee',
#   'story': 'is a key person at',
#   'target': 'Project Sukanya',
#   'weight': 1},
#  {'source': 'Chandra Shekhar Ghosh ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Chandra Shekhar Ghosh ',
#   'story': 'is a key person at',
#   'target': 'Bandhan',
#   'weight': 1},
#  {'source': 'Deep Purokayastha ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Deep Purokayastha ',
#   'story': 'is a key person at',
#   'target': 'PRAAJAK',
#   'weight': 1},
#  {'source': 'Dr. Kedar Ranjan Banerjee ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Dr. Kedar Ranjan Banerjee ',
#   'story': 'is a key person at',
#   'target': 'NIBS Kolkata',
#   'weight': 1},
#  {'source': 'Dr. Purobie Bose ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Dr. Purobie Bose ',
#   'story': 'is a key person at',
#   'target': 'Society For Remedial Education Assessment Counselling Handicapped',
#   'weight': 1},
#  {'source': 'Indrani Chakravarty',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Indrani Chakravarty',
#   'story': 'is a key person at',
#   'target': 'Calcutta Metropolitan Institute of Gentrology',
#   'weight': 1},
#  {'source': 'Kallol Ghosh ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Kallol Ghosh ',
#   'story': 'is a key person at',
#   'target': 'Organisation For Friends, Energy and Resources (OFFER)',
#   'weight': 1},
#  {'source': 'Krishna Roy ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Krishna Roy ',
#   'story': 'is a key person at',
#   'target': 'Nari Nirjatan Pratirodh Mancha',
#   'weight': 1},
#  {'source': 'Mina Das',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Mina Das',
#   'story': 'is a key person at',
#   'target': 'Nishtha',
#   'weight': 1},
#  {'source': 'Raja Menon',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Raja Menon',
#   'story': 'is a key person at',
#   'target': 'Jeevika Development Society',
#   'weight': 1},
#  {'source': 'Ratnaboli Ray ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Ratnaboli Ray ',
#   'story': 'is a key person at',
#   'target': 'Anjali Mental Health Rights Organisation',
#   'weight': 1},
#  {'source': 'S.M. Cyril Mooney',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'S.M. Cyril Mooney',
#   'story': 'is a key person at',
#   'target': 'Loreto House Sealdah',
#   'weight': 1},
#  {'source': 'S. Bandopadhyay',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'S. Bandopadhyay',
#   'story': 'is a key person at',
#   'target': 'Navadiganta',
#   'weight': 1},
#  {'source': 'Sohini Chakraborty',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Sohini Chakraborty',
#   'story': 'is a key person at',
#   'target': 'Kolkata Sanved',
#   'weight': 1},
#  {'source': 'Tulika Das ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Tulika Das ',
#   'story': 'is a key person at',
#   'target': 'Sanchar',
#   'weight': 1},
#  {'source': 'Kamal Kanti Banik',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Kamal Kanti Banik',
#   'story': 'is a key person at',
#   'target': 'Dishari',
#   'weight': 1},
#  {'source': 'Chingmak Sipong Chang',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Chingmak Sipong Chang',
#   'story': 'is a key person at',
#   'target': 'Eleutheros Christian Society',
#   'weight': 1},
#  {'source': 'John J',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'John J',
#   'story': 'is a key person at',
#   'target': 'Grassroot Tea Corporation',
#   'weight': 1},
#  {'source': 'Paramita Banerjee',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Paramita Banerjee',
#   'story': 'is a key person at',
#   'target': 'Individual Paramita Banerjee',
#   'weight': 1},
#  {'source': 'Dinesh Kumar Mishra',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Dinesh Kumar Mishra',
#   'story': 'is a key person at',
#   'target': 'Barh Mukti Abhiyan (Freedom from Floods Campaign)',
#   'weight': 1},
#  {'source': 'Mohammad Nooruddin Amin',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Mohammad Nooruddin Amin',
#   'story': 'is a key person at',
#   'target': 'Adhikar',
#   'weight': 1},
#  {'source': 'Prabhat Kumar',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Prabhat Kumar',
#   'story': 'is a key person at',
#   'target': 'Kisan Vikash Trust',
#   'weight': 1},
#  {'source': 'Chhanda Bose',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Chhanda Bose',
#   'story': 'is a key person at',
#   'target': 'Individual India',
#   'weight': 1},
#  {'source': 'Maitreyee Chatterjee',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Maitreyee Chatterjee',
#   'story': 'is a key person at',
#   'target': 'Nari Nirjatan Partirodh Mancha',
#   'weight': 1},
#  {'source': 'Ashru Mandal',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Ashru Mandal',
#   'story': 'is a key person at',
#   'target': 'Ashru Mandal Individual',
#   'weight': 1},
#  {'source': 'Jude Henriques',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Jude Henriques',
#   'story': 'is a key person at',
#   'target': 'Individual India',
#   'weight': 1},
#  {'source': 'Soma Sen gupta',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Soma Sen gupta',
#   'story': 'is a key person at',
#   'target': 'Sanhita',
#   'weight': 1},
#  {'source': 'Samir Bordoloi',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Ahsan Rony',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Ahsan Rony',
#   'story': 'is a key person at',
#   'target': 'Green savers association',
#   'weight': 1},
#  {'source': 'Nazma Akter',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Nazma Akter',
#   'story': 'is a key person at',
#   'target': 'Awaj Foundation',
#   'weight': 1},
#  {'source': 'Albert Mollah',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Albert Mollah',
#   'story': 'is a key person at',
#   'target': 'Access Bangladesh',
#   'weight': 1},
#  {'source': 'Choitresh Kumar Ganguly',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Choitresh Kumar Ganguly',
#   'story': 'is a key person at',
#   'target': 'Timbaktu Collective',
#   'weight': 1},
#  {'source': 'Dinesh Kumar',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Dinesh Kumar',
#   'story': 'is a key person at',
#   'target': 'Earth 360',
#   'weight': 1},
#  {'source': 'Akkai Padmashali',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Akkai Padmashali',
#   'story': 'is a key person at',
#   'target': 'Ondede',
#   'weight': 1},
#  {'source': 'Alphonse Jemonie',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Alphonse Jemonie',
#   'story': 'is a key person at',
#   'target': 'Goodwill International Association',
#   'weight': 1},
#  {'source': 'Anselm Rosario',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Anselm Rosario',
#   'story': 'is a key person at',
#   'target': 'Mythri Sarva Seva Samithi',
#   'weight': 1},
#  {'source': 'Anup Akkihal',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Anup Akkihal',
#   'story': 'is a key person at',
#   'target': 'Logistimo',
#   'weight': 1},
#  {'source': 'Ashok Kumar Rau',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Ashok Kumar Rau',
#   'story': 'is a key person at',
#   'target': 'Freedom Foundation',
#   'weight': 1},
#  {'source': 'Ashwin Naik',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Ashwin Naik',
#   'story': 'is a key person at',
#   'target': 'Vaatsalya',
#   'weight': 1},
#  {'source': 'Ayyappa Mahadevappa Masagi',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Ayyappa Mahadevappa Masagi',
#   'story': 'is a key person at',
#   'target': 'Water literacy foundation and rainwater concepts ind pvt ltd',
#   'weight': 1},
#  {'source': 'C V Madhukar',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'C V Madhukar',
#   'story': 'is a key person at',
#   'target': 'PRS Legislative Research',
#   'weight': 1},
#  {'source': 'Christopher Rego',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Christopher Rego',
#   'story': 'is a key person at',
#   'target': 'The Sunbird Trust',
#   'weight': 1},
#  {'source': 'Damodar Acharya',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Damodar Acharya',
#   'story': 'is a key person at',
#   'target': 'The Concerned for Working Children',
#   'weight': 1},
#  {'source': 'Devi Prasad Shetty',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Devi Prasad Shetty',
#   'story': 'is a key person at',
#   'target': 'Narayana Hrudayalaya',
#   'weight': 1},
#  {'source': 'Edith Elliott',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Edith Elliott',
#   'story': 'is a key person at',
#   'target': 'Noora Health',
#   'weight': 1},
#  {'source': 'Anup Nair',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Anup Nair',
#   'story': 'is a key person at',
#   'target': 'LEDs(Local Economic Development Society)',
#   'weight': 1},
#  {'source': 'AR Palaniswamy',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'AR Palaniswamy',
#   'story': 'is a key person at',
#   'target': 'Society for Educational and Economic Development(founded 1981)',
#   'weight': 1},
#  {'source': 'B. Sailakshmi',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'B. Sailakshmi',
#   'story': 'is a key person at',
#   'target': 'Ekam',
#   'weight': 1},
#  {'source': 'Balaji Sampath',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Balaji Sampath',
#   'story': 'is a key person at',
#   'target': 'Aid India',
#   'weight': 1},
#  {'source': 'Elango Rangaswamy ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Elango Rangaswamy ',
#   'story': 'is a key person at',
#   'target': 'Trust for Village Self Governance',
#   'weight': 1},
#  {'source': 'Errabelli Madan Mohan Rao',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Errabelli Madan Mohan Rao',
#   'story': 'is a key person at',
#   'target': 'Rural Telecom Foundation',
#   'weight': 1},
#  {'source': 'Gananath S N',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Gananath S N',
#   'story': 'is a key person at',
#   'target': 'Suvidya',
#   'weight': 1},
#  {'source': 'Gangadhar Patil',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Gangadhar Patil',
#   'story': 'is a key person at',
#   'target': '101 Reporters',
#   'weight': 1},
#  {'source': 'Gangadharan Gopinathan Geethalayam',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Gangadharan Gopinathan Geethalayam',
#   'story': 'is a key person at',
#   'target': 'LSPSS ( Lok Swasthya Parampara Samvardhan Samiti )',
#   'weight': 1},
#  {'source': 'Geeta Ramanujam',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Geeta Ramanujam',
#   'story': 'is a key person at',
#   'target': '"Kathalaya Academy of Storytelling"',
#   'weight': 1},
#  {'source': 'Gijs Spoor',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Gita Ramaswamy',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Gita Ramaswamy',
#   'story': 'is a key person at',
#   'target': 'Ibrahimpatnam Vyavasaya Coolie Sangham',
#   'weight': 1},
#  {'source': 'Glory Alexander',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Glory Alexander',
#   'story': 'is a key person at',
#   'target': 'Asha Foundation',
#   'weight': 1},
#  {'source': 'GNS Reddy',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'GNS Reddy',
#   'story': 'is a key person at',
#   'target': 'Akshayakalpa',
#   'weight': 1},
#  {'source': 'Dr. Gokulan Bhargavi Gopinath',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Dr. Gokulan Bhargavi Gopinath',
#   'story': 'is a key person at',
#   'target': 'Sudarshanam Netra Chikitsalayam',
#   'weight': 1},
#  {'source': 'Govindaiah Krishna Prasad',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Govindaiah Krishna Prasad',
#   'story': 'is a key person at',
#   'target': 'Sahadja Samrudha',
#   'weight': 1},
#  {'source': 'Hanumappa Sudarshan',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Hanumappa Sudarshan',
#   'story': 'is a key person at',
#   'target': 'Vivekananda Girijana Kalyana Kendra (VGKK) & Karuna Trust',
#   'weight': 1},
#  {'source': 'Hardika Shah',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Hardika Shah',
#   'story': 'is a key person at',
#   'target': 'Kinara Capital',
#   'weight': 1},
#  {'source': 'Harish Hande',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Harish Hande',
#   'story': 'is a key person at',
#   'target': 'SELCO',
#   'weight': 1},
#  {'source': 'Harry Andrews',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Harry Andrews',
#   'story': 'is a key person at',
#   'target': 'Centre for Herpetology',
#   'weight': 1},
#  {'source': 'Isidore Phillips',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Isidore Phillips',
#   'story': 'is a key person at',
#   'target': 'Divya Disha',
#   'weight': 1},
#  {'source': 'Janardhana Gungurumale',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Janardhana Gungurumale',
#   'story': 'is a key person at',
#   'target': 'SOSAD',
#   'weight': 1},
#  {'source': 'Jasmeen Patheja',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Jasmeen Patheja',
#   'story': 'is a key person at',
#   'target': 'Blank Noise',
#   'weight': 1},
#  {'source': 'Jayaprakash Rao Polsani',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Jayaprakash Rao Polsani',
#   'story': 'is a key person at',
#   'target': 'NA',
#   'weight': 1},
#  {'source': 'Jithin Nedumala',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Jithin Nedumala',
#   'story': 'is a key person at',
#   'target': 'Make a Difference',
#   'weight': 1},
#  {'source': 'Kavitha Krishnamoorthy',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Kavitha Krishnamoorthy',
#   'story': 'is a key person at',
#   'target': 'Kilikili',
#   'weight': 1},
#  {'source': 'Kousalya Periasamy',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Kousalya Periasamy',
#   'story': 'is a key person at',
#   'target': 'Positive Women Network PWN+',
#   'weight': 1},
#  {'source': 'Kuldeep Dantewadia',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Kuldeep Dantewadia',
#   'story': 'is a key person at',
#   'target': 'Reap Benefit',
#   'weight': 1},
#  {'source': 'Lalitha Raghuram',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Lalitha Raghuram',
#   'story': 'is a key person at',
#   'target': 'Mohan Foundation',
#   'weight': 1},
#  {'source': 'Latha Anantha',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Latha Anantha',
#   'story': 'is a key person at',
#   'target': 'River Research Center',
#   'weight': 1},
#  {'source': 'M. Prakasamma',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'M. Prakasamma',
#   'story': 'is a key person at',
#   'target': 'ANSWERS',
#   'weight': 1},
#  {'source': 'Mananjeri Basu Nirmal',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Mananjeri Basu Nirmal',
#   'story': 'is a key person at',
#   'target': 'ExNoRa International',
#   'weight': 1},
#  {'source': 'Mandira Kumar',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Mandira Kumar',
#   'story': 'is a key person at',
#   'target': 'Sutradhar Educational Resource Centre',
#   'weight': 1},
#  {'source': 'Manoj Kumar',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Manoj Kumar',
#   'story': 'is a key person at',
#   'target': 'Mental Health Action Trust',
#   'weight': 1},
#  {'source': 'Masthi Papamma',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Masthi Papamma',
#   'story': 'is a key person at',
#   'target': 'Grameen Mahila Okkuta',
#   'weight': 1},
#  {'source': 'Mathew Jose',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Mathew Jose',
#   'story': 'is a key person at',
#   'target': 'PaperMan',
#   'weight': 1},
#  {'source': 'Mathew M.V.',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Mathew M.V.',
#   'story': 'is a key person at',
#   'target': 'NOCER-INDIA (National organization for Consumer Education and Research)',
#   'weight': 1},
#  {'source': 'Meera K',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Meera K',
#   'story': 'is a key person at',
#   'target': 'Citizen Matters',
#   'weight': 1},
#  {'source': 'Monish Anand',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Monish Anand',
#   'story': 'is a key person at',
#   'target': 'Datasigns Technologies',
#   'weight': 1},
#  {'source': 'Mukteshwari Kaushik Bosco',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Mukteshwari Kaushik Bosco',
#   'story': 'is a key person at',
#   'target': 'Healing Fields Foundation',
#   'weight': 1},
#  {'source': 'Murali Mohan',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Murali Mohan',
#   'story': 'is a key person at',
#   'target': 'Sadhana',
#   'weight': 1},
#  {'source': 'Muthu Peraman',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Muthu Peraman',
#   'story': 'is a key person at',
#   'target': 'Trust HELP',
#   'weight': 1},
#  {'source': 'Nagamalai Muthu Velayutham',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Nagamalai Muthu Velayutham',
#   'story': 'is a key person at',
#   'target': 'Covenant Centre for Development',
#   'weight': 1},
#  {'source': 'Nalini Nayak',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Nalini Nayak',
#   'story': 'is a key person at',
#   'target': 'SEWA Thiruvananthapuram',
#   'weight': 1},
#  {'source': 'Nandini Mundkur',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Nandini Mundkur',
#   'story': 'is a key person at',
#   'target': 'Center for Child Development & Disabilities',
#   'weight': 1},
#  {'source': 'Nirmala Srinivasan',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Nirmala Srinivasan',
#   'story': 'is a key person at',
#   'target': 'Action For Mental Illness',
#   'weight': 1},
#  {'source': 'Pallavi Gupta',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Pallavi Gupta',
#   'story': 'is a key person at',
#   'target': 'FifthEstate Trust',
#   'weight': 1},
#  {'source': 'Pandurang Ganapati Hegde',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Pandurang Ganapati Hegde',
#   'story': 'is a key person at',
#   'target': 'Appiko Andolan',
#   'weight': 1},
#  {'source': 'Parashurama Mynakanahalli Lingegowda',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Parashurama Mynakanahalli Lingegowda',
#   'story': 'is a key person at',
#   'target': 'Odanadi Seva Trust',
#   'weight': 1},
#  {'source': 'Patricia',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Patricia',
#   'story': 'is a key person at',
#   'target': 'Institute for Rural Health Studies',
#   'weight': 1},
#  {'source': 'Paul Basil',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Paul Basil',
#   'story': 'is a key person at',
#   'target': 'Rural Innovations Network',
#   'weight': 1},
#  {'source': 'Priscilla Nirmalakumari',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Priscilla Nirmalakumari',
#   'story': 'is a key person at',
#   'target': 'Ecumenical Church Loan Fund ( ECLOF International )',
#   'weight': 1},
#  {'source': 'Rajendra Y J',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Rajendra Y J',
#   'story': 'is a key person at',
#   'target': 'JanaSahyog-An Urban Resource Centre',
#   'weight': 1},
#  {'source': 'Rama Anumula',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Rama Anumula',
#   'story': 'is a key person at',
#   'target': 'Rishi Valley Institute for Educational Resources (RIVER)',
#   'weight': 1},
#  {'source': 'Ramachandra V Gunari',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Ramachandra V Gunari',
#   'story': 'is a key person at',
#   'target': 'Ankura',
#   'weight': 1},
#  {'source': 'Ramakrishna NK',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Ramakrishna NK',
#   'story': 'is a key person at',
#   'target': 'Rang De',
#   'weight': 1},
#  {'source': 'Ramji Raghavan ',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Ramji Raghavan ',
#   'story': 'is a key person at',
#   'target': 'Agastya International foundation',
#   'weight': 1},
#  {'source': 'Ramya Venkataraman',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Ramya Venkataraman',
#   'story': 'is a key person at',
#   'target': 'Center For Teacher Accreditation',
#   'weight': 1},
#  {'source': 'Rao Padmanabha Yerravalli',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Rao Padmanabha Yerravalli',
#   'story': 'is a key person at',
#   'target': 'Rishi Valley Institute for Educational Resources (RIVER)',
#   'weight': 1},
#  {'source': 'Raveendran Kannan',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Ravichandra Raju',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Ravichandra Raju',
#   'story': 'is a key person at',
#   'target': 'Bhavishya Bharthi',
#   'weight': 1},
#  {'source': 'Renu Appachu',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Renu Appachu',
#   'story': 'is a key person at',
#   'target': 'Jagruiti',
#   'weight': 1},
#  {'source': 'Romulus Earl Whitaker',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Romulus Earl Whitaker',
#   'story': 'is a key person at',
#   'target': 'Agumbe Rainforest Research Station',
#   'weight': 1},
#  {'source': 'S.L.N Swamy',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'S.L.N Swamy',
#   'story': 'is a key person at',
#   'target': 'The Adventurers',
#   'weight': 1},
#  {'source': 'Sagari Radhika Ramdas',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Sameer Subhash Sawarkar',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Sameer Subhash Sawarkar',
#   'story': 'is a key person at',
#   'target': 'Neurosynaptic Communications Pvt Ltd',
#   'weight': 1},
#  {'source': 'Sampath JM',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Sampath JM',
#   'story': 'is a key person at',
#   'target': 'Arpitha  Associates Pvt. Ltd',
#   'weight': 1},
#  {'source': 33, 'story': 'is a fellow at', 'target': 'Ashoka', 'weight': 1},
#  {'source': 33,
#   'story': 'is a key person at',
#   'target': 'Amar Seva Sangam',
#   'weight': 1},
#  {'source': 'Santhanagopalan Rajagopalan',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Santhanagopalan Rajagopalan',
#   'story': 'is a key person at',
#   'target': 'Technology Informatics Design Endeavour',
#   'weight': 1},
#  {'source': 'Sarat Babu Vasireddy',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Sarat Babu Vasireddy',
#   'story': 'is a key person at',
#   'target': 'Pratyamanya',
#   'weight': 1},
#  {'source': 'Shanti Raghavan',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Shanti Raghavan',
#   'story': 'is a key person at',
#   'target': 'Enable India',
#   'weight': 1},
#  {'source': 'Shivaram Pailoor',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1},
#  {'source': 'Shivaram Pailoor',
#   'story': 'is a key person at',
#   'target': 'CAAM ( Centre for Alternative Agricultur Media )',
#   'weight': 1},
#  {'source': 'Shree Padre',
#   'story': 'is a fellow at',
#   'target': 'Ashoka',
#   'weight': 1}]

# %%
#def update_nodes(edges):
nodescur=set(list(edges.source.unique())+list(edges.target.unique()))
nodes=nodesheet.get_as_df()
list(nodes.id.unique())
for node in nodescur:
    if node not in list(nodes.id.unique()):
        print(node)
        nodesheet.insert_rows(nodesheet.rows,values=[node,'Unknown'], inherit=True)
    xetrapal.karma.wait(waittime="short")
# Out:
# 2020-08-10 18:11:11 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 1 seconds
# 2020-08-10 18:11:12 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 1 seconds
# 2020-08-10 18:11:13 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 4 seconds
# 2020-08-10 18:11:17 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# 2020-08-10 18:11:20 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# 33
# 2020-08-10 18:11:26 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 1 seconds
# 2020-08-10 18:11:28 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# 2020-08-10 18:11:31 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 9 seconds
# 2020-08-10 18:11:40 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 7 seconds
# 2020-08-10 18:11:47 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 4 seconds
# 2020-08-10 18:11:51 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# 2020-08-10 18:11:56 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 4 seconds
# 2020-08-10 18:12:00 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 8 seconds
# 2020-08-10 18:12:08 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 7 seconds
# 2020-08-10 18:12:15 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 0 seconds
# 2020-08-10 18:12:15 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 8 seconds
# 2020-08-10 18:12:23 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 1 seconds
# 2020-08-10 18:12:24 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 1 seconds
# 2020-08-10 18:12:25 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 7 seconds
# 2020-08-10 18:12:32 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 7 seconds
# 2020-08-10 18:12:39 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# 2020-08-10 18:12:44 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# 2020-08-10 18:12:47 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# 2020-08-10 18:12:53 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 2 seconds
# 2020-08-10 18:12:55 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# 2020-08-10 18:13:01 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# 2020-08-10 18:13:07 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# 2020-08-10 18:13:10 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# 2020-08-10 18:13:16 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 8 seconds
# 2020-08-10 18:13:24 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 2 seconds
# 2020-08-10 18:13:26 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# 2020-08-10 18:13:32 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# 2020-08-10 18:13:35 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 2 seconds
# 2020-08-10 18:13:37 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 9 seconds
# 2020-08-10 18:13:46 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 8 seconds
# 2020-08-10 18:13:54 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# 2020-08-10 18:13:59 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# 2020-08-10 18:14:04 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# Shivaram Pailoor
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-24-9586e8b4f744> in <module>
#       6     if node not in list(nodes.id.unique()):
#       7         print(node)
# ----> 8         nodesheet.insert_rows(nodesheet.rows,values=[node,'Unknown'], inherit=True)
#       9     xetrapal.karma.wait(waittime="short")
#      10
#
# /usr/local/lib/python3.8/dist-packages/pygsheets/worksheet.py in insert_rows(self, row, number, values, inherit)
#     801                                        'range': {'sheetId': self.id, 'dimension': 'ROWS',
#     802                                                  'endIndex': (row+number), 'startIndex': row}}}
# --> 803         self.client.sheet.batch_update(self.spreadsheet.id, request)
#     804         self.jsonSheet['properties']['gridProperties']['rowCount'] = self.rows + number
#     805         if values:
#
# /usr/local/lib/python3.8/dist-packages/pygsheets/sheet.py in batch_update(self, spreadsheet_id, requests, **kwargs)
#      92         request = self.service.spreadsheets().batchUpdate(spreadsheetId=spreadsheet_id,
#      93                                                           body=body, **kwargs)
# ---> 94         return self._execute_requests(request)
#      95
#      96     def create(self, title, template=None, **kwargs):
#
# /usr/local/lib/python3.8/dist-packages/pygsheets/sheet.py in _execute_requests(self, request)
#     349         """
#     350         try:
# --> 351             response = request.execute(num_retries=self.retries)
#     352         except HttpError as error:
#     353             if error.resp['status'] == '429':
#
# /usr/local/lib/python3.8/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# /usr/local/lib/python3.8/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     905             callback(resp)
#     906         if resp.status >= 300:
# --> 907             raise HttpError(resp, content, uri=self.uri)
#     908         return self.postproc(resp, content)
#     909
#
# HttpError: <HttpError 400 when requesting https://sheets.googleapis.com/v4/spreadsheets/1CihUjjhCueFBGB74d1MZnIx-SpJxQCWuGE8IKVP8B6k:batchUpdate?fields=%2A&alt=json returned "Invalid requests[0].insertDimension: range.startIndex is larger than current grid size (347)">

# %%
nodes=nodesheet.get_as_df()

nodes['group']=nodes.category.apply(lambda x: list(nodes.category.unique()).index(x)+1)
nodes
# Out:
#                                                     id category  group
# 0                                                  1MG  Unknown      1
# 1                                             Abhishek   person      2
# 2                                         AccessHealth     INGO      3
# 3                                  Adhyayan Foundation      NGO      4
# 4                                        Adith Haridas   person      2
# 5                                      Aditya Dipankar   person      2
# 6                                          Akash Upase   person      2
# 7                                   Akshara Foundation  Unknown      1
# 8                                               Anudip  Unknown      1
# 9                                       Arandeep Singh   person      2
# 10                                   Arjun Venkatraman   person      2
# 11                                        Ashima Joshi   person      2
# 12                                      Ashish Birulee   person      2
# 13                                              Ashoka  network      5
# 14                                      Aspiring Minds  Unknown      1
# 15                                   Axio Biosolutions  Unknown      1
# 16                                          Bamshankar   person      2
# 17                         Bharat Inclusion Initiative  Unknown      1
# 18                                               Bijak  Unknown      1
# 19                                                BMGF    donor      6
# 20                                          Bolti Band      COP      7
# 21                                      Bong Book Cafe  project      8
# 22                                              Bridge  Unknown      1
# 23                                                 CAF  Unknown      1
# 24                                                CDFI      NGO      4
# 25                                               Centa  Unknown      1
# 26              Centre for Social and Behaviour Change  Unknown      1
# 27                                                 CIS      NGO      4
# 28                                             CIVICUS     INGO      3
# 29                                         Counterpart     INGO      3
# ..                                                 ...      ...    ...
# 317                          Govindaiah Krishna Prasad  Unknown      1
# 318                                    S. Bandopadhyay  Unknown      1
# 319                          Mukteshwari Kaushik Bosco  Unknown      1
# 320                          Mythri Sarva Seva Samithi  Unknown      1
# 321                                    Ramji Raghavan   Unknown      1
# 322                                  Make a Difference  Unknown      1
# 323                                    Nandini Mundkur  Unknown      1
# 324              Sutradhar Educational Resource Centre  Unknown      1
# 325  LSPSS ( Lok Swasthya Parampara Samvardhan Sami...  Unknown      1
# 326                               Kaushalya Foundation  Unknown      1
# 327                                   Abhijit Bardhan   Unknown      1
# 328                                  Jagadish Pradhan   Unknown      1
# 329                               Loreto House Sealdah  Unknown      1
# 330                                 Elango Rangaswamy   Unknown      1
# 331                            Priscilla Nirmalakumari  Unknown      1
# 332                            Dr Bibhu Kalyan Mohanty  Unknown      1
# 333  Organisation For Friends, Energy and Resources...  Unknown      1
# 334                                          Anup Nair  Unknown      1
# 335                                           Kilikili  Unknown      1
# 336                                       Krishna Roy   Unknown      1
# 337                                 Odanadi Seva Trust  Unknown      1
# 338                                              Ekjut  Unknown      1
# 339                                 Devi Prasad Shetty  Unknown      1
# 340                                   Anuradha Kapoor   Unknown      1
# 341                                    Awaj Foundation  Unknown      1
# 342           LEDs(Local Economic Development Society)  Unknown      1
# 343                          Errabelli Madan Mohan Rao  Unknown      1
# 344                                     Jude Henriques  Unknown      1
# 345                                     Deepjyoti Sonu  Unknown      1
# 346                                                                 12
#
# [347 rows x 3 columns]

# %%
with open("RawData/graphdata.json","w") as f:
    f.write(json.dumps({"nodes":nodes.to_dict(orient="records"),"links":links}))
    #f.write({"nodes":nodes.to_json(orient="records"),"links":links})

# %%
list(nodes.category.unique())
# Out:
# ['Unknown',
#  'person',
#  'INGO',
#  'NGO',
#  'network',
#  'donor',
#  'COP',
#  'project',
#  'event',
#  'institution',
#  'company']

# %%
def get_omidyar_invs():
    page=requests.get("https://www.omidyarnetwork.in/sitemap")
    soup = BeautifulSoup(page.text, 'html.parser')
    invlist=[]
    for section in soup.find_all("section", {"class":re.compile("teamSec*")}):
        try:
            category=section.find("div",{"class":"sitemap_sub_section_head"}).text.lstrip("\n").rstrip("\n")
            #print(category)
            for sec in section.find_all("div",{"class":"col-md-6"}):
                inv_type=sec.find("div",{"class":"sitemap_sub_sec_subhead"}).text.lstrip("\n").rstrip("\n")
                #print(inv_type)
                for inv in sec.find_all("a"):
                    url=inv.get("href")
                    text=inv.text.lstrip("\n").rstrip("\n")
                    print(text,url,inv_type,category)
                    invlist.append({"inv_name":text,"url":url,"type":inv_type,"category":category})
                    #omidyarsheet.insert_rows(omidyarsheet.rows,values=[text,url,inv_type,category], inherit=True)


        except:
            #print("No Section Head")
            break;
        return invlist

# %%
#omidyarsheet.set_dataframe(pandas.DataFrame(invlist),(1,1))
def update_omidyar_sheet():
    invlist=omidyarsheet.get_as_df()
    invlist
    for inv in invlist.inv_name:
        print(["Omidyar", "funds", inv])
        edgesheet.insert_rows(edgesheet.rows,values=["Omidyar", "funds", inv], inherit=True)
        
#update_omidyar_sheet()

# %%
ashokasheet=gd.open("Ashoka Fellows")
fellows=[]
for sheet in ashokasheet.worksheets():
    sheetdf=sheet.get_as_df()
    for name in sheetdf['Full Name']:
        fellows.append(str(name).lstrip().rstrip())

# %%
fellows=list(set(fellows))
fellows.remove("33")
fellows,len(fellows)
# Out:
# (['Deep Purokayastha',
#   'Flavia Agnes',
#   'Pranjal Baruah',
#   'Akkai Padmashali',
#   'Rita Banerji',
#   'Jaya Prakash Rao',
#   'Amitav Virmani',
#   'Vibha Gupta',
#   'Pranil Naik',
#   'Akshay Saxena',
#   'Sharath Jeevan',
#   'Pankaj Jain',
#   'Pandurang Ganapati Hegde',
#   'Solomon Jaya Prakash',
#   'Haushala Prasad Shriram Mishra',
#   'Sonam Wangchuk',
#   'Hilmi Quraishi',
#   'Kailash Satyarthi',
#   'Jessica Mayberry',
#   'Sanvardeep Oberoi',
#   'Isidore Phillips',
#   'Ashwin Naik',
#   'Anjali Bharadwaj',
#   'Sunitha Krishnan',
#   'Suprabha Seshan',
#   'Naginbhai Shah',
#   'S.L.N Swamy',
#   'AR Palaniswamy',
#   'KA Thomas',
#   'Pravin Khandpasole',
#   'Chhanda Bose',
#   'Ramya Venkataraman',
#   'Anil Patil',
#   'S. Bandopadhyay',
#   'Vijay Singh Aditya',
#   'Sudhirendar Sharma',
#   'Rao Padmanabha Yerravalli',
#   'Dr. Purobie Bose',
#   'Rashneh Pardiwala',
#   'Parul Sheth',
#   'Parashurama Mynakanahalli Lingegowda',
#   'Nirmala Srinivasan',
#   'Sujit Sinha',
#   'Shanti Raghavan',
#   'Ravi Aggarwal',
#   'Hanif Lakdawala',
#   'Akanksha Hazari',
#   'Sushobha Barve',
#   'Ritwick Dutta',
#   'Romulus Earl Whitaker',
#   'Balaji Sampath',
#   'Anindita Majumdar',
#   'Lalitha Raghuram',
#   'John J',
#   'Shilpi Kapoor',
#   'Sunita Bagal',
#   'Shashank Kumar',
#   'Madhavi Kuckreja',
#   'Maitreyee Chatterjee',
#   'Aman Singh',
#   'Monish Anand',
#   'Kavita Anand',
#   'Umesh Malhotra',
#   'Raju Purohit',
#   'Shakil Ahmed',
#   'Anita Ahuja',
#   'Hardika Shah',
#   'Partap chauhan',
#   'Vivek Pandit',
#   'Sheilu Srinivasan',
#   'Sanjay Bapat',
#   'Bhargavi Davar',
#   'Susheela Bhan',
#   'Sumita Ghose',
#   'Soma Sengupta',
#   'Sreeja S',
#   'Chingmak Sipong Chang',
#   'Mukteshwari Kaushik Bosco',
#   'Samir Bordoloi',
#   'Nimisha Desai',
#   'Dr. Ravindra Pandurang Shetye',
#   'Harini Kakkeri',
#   'Suresh Kumar',
#   'NoorJehan Safia Niaz',
#   'Maharukh Adenwalla',
#   'Balkrishna Renake',
#   'Anjali Gopalan',
#   'Rashneh Noshir Pardiwala',
#   'Ayyappa Mahadevappa Masagi',
#   'Jyoti Subhash Mhapsekar',
#   'Sundara Narayana Patro',
#   'Priscilla Nirmalakumari',
#   'Ramachandra V Gunari',
#   'Pushkin Phartiyal',
#   'Thara Srinivasan',
#   'Ashraf Patel',
#   'Rakesh Kumar Jaiswal',
#   'Ahsan Rony',
#   'Tripura Kashyap',
#   'Anil Gajanan Shaligram',
#   'Amlan Kusum Ganguly',
#   'Nidhi Prahba Tewari',
#   'Prabhat Kumar',
#   'Ravindranath',
#   'Choitresh Kumar Ganguly',
#   'Pratibha Shinde',
#   'Aromar Revi',
#   'Anuradha Mohit',
#   'Kamal Kanti Banik',
#   'Kabir Vajpeyi',
#   'Krishna Chandra Mishra',
#   'Brij Kothari',
#   'Ravichandra Raju',
#   'Reshma Valliappan',
#   'Elango Rangaswamy',
#   'Vandana Gupta',
#   'Debashish Nayak',
#   'Samuel Warrack Goldman',
#   'Raveendran Kannan',
#   'Mathew M.V.',
#   'Bindeshwar Pathak',
#   'Mananjeri Basu Nirmal',
#   'Saurav Kumar Ghosh',
#   'Ashif Shaikh',
#   'Subroto Das',
#   'Ramakrishna NK',
#   'Susheela Kumaran Andezhath',
#   'Janaki Rajan',
#   'Patricia',
#   'Ashok Mahipat Kadam',
#   'Harry Andrews',
#   'Shaheen Mistri',
#   'Aparna Banerjee',
#   'Sonam Jorgyes',
#   'Muthu Velayutham',
#   'Belinda Wright',
#   'Neichute Doulo',
#   'Tarak Kate',
#   'Pavitra Mohan',
#   'Pradeep Ghosh',
#   'Mohammad Tarique Qureshi',
#   'Errabelli Madan Mohan Rao',
#   'Jasmeen Patheja',
#   'Teesta Setalvad',
#   'Shubhendu Sharma',
#   'Minal Doshi',
#   'Deendayal Rangaraj',
#   'Santosh Raghunath Gondhalekar',
#   'Anuradha Kapoor',
#   'Bina Gajendra Lashkari',
#   'Purobie Bose',
#   'Falgun Sheth',
#   'Indrani Chakravarty',
#   'Sneh Kumar',
#   'Madhav Chavan',
#   'Dr Bibhu Kalyan Mohanty',
#   'Lisa Danielle Heydlauff',
#   'Mohan Hirabai Hiralal',
#   'Janardhana Gungurumale',
#   'Kitayun Aspi Rustom',
#   'Sanjeev Kumar',
#   'Sachin kumar Jain',
#   'Sumaira Abdulali',
#   'Vasant Babaji Gangavane',
#   'Uppath Jaikumar',
#   'Anselm Rosario',
#   'Manoj Kumar',
#   'Mittal Patel',
#   'Sunanda Mane',
#   'Urvashi Sahni',
#   'Jayaprakash Rao Polsani',
#   'Rama Anumula',
#   'Rehana Adib',
#   'Sunil Daga Khairnar',
#   'Albert Mollah',
#   'Suresh Kushtagi',
#   'Michael Prakash',
#   'Sameer Subhash Sawarkar',
#   'Dinesh Kumar Mishra',
#   'Rikin Gandhi',
#   'Adarsh Kumar',
#   'Roland Martins',
#   'Rita Panicker-Pinto',
#   'Ashru Mandal',
#   'Deborah McCauley',
#   'Chandra Shekhar Ghosh',
#   'Sharafat Ali Azad',
#   'Kishore Rithe',
#   'George Abraham',
#   'Dipendra Manocha',
#   'Sachidanand Bharati',
#   'S. Santhi',
#   'Rajendra Y J',
#   'Kuldeep Dantewadia',
#   'Gaurang Raval',
#   'Eldred Maurice Tellis',
#   'Bastu Rege',
#   "Andreas D'Souza",
#   'Nalini Shaligram',
#   'Mina Das',
#   'Minal Kavishwar',
#   'Rajiv Khandelwal',
#   'Enakshi Ganguly',
#   'Masthi Papamma',
#   'Chetna Gala Sinha',
#   'Dhrubajyoti Ghosh',
#   'Anil Prakash Joshi',
#   'Gijs Spoor',
#   'Gaurav Singh',
#   'Dadasaheb More',
#   'Rathindranath Roy',
#   'Paromita Goswami',
#   'S.M Cyril Mooney',
#   'Ramesh Kumar',
#   'Yogendra Singh',
#   'Murali Mohan',
#   'Avinash Shirke',
#   'Kaustubh Ashok Pandharipande',
#   'Karan Grover',
#   'Ishita Khanna',
#   'Abhijit Bardhan',
#   'Ratnaboli Ray',
#   'Jyoti Sharma',
#   'Gita Ramaswamy',
#   'Mohammad Nooruddin Amin',
#   'Krishna Roy',
#   'John Abraham',
#   'Beena Chintalapuri',
#   'Sekhar Raghavan',
#   'Rajiv Balkrishna Vartak',
#   'Shree Padre',
#   'Javed Abidi',
#   'Pallavi Gupta',
#   'Ramji Raghavan',
#   'Santhanagopalan Rajagopalan',
#   'Binalakshmi Nepram',
#   'Krishna Mishra',
#   'Bezwada Wilson',
#   'Merry Barua',
#   'Ramesh Nandwana',
#   'E. K. Shaji',
#   'Matthew Spacie',
#   'Sriram V Ayer',
#   'Hasina Khan',
#   'Kavitha Krishnamoorthy',
#   'Anshu K. Gupta',
#   'Rajendra Joshi',
#   'Jeroo Billimoria',
#   'Amol Chandrabhan Goje',
#   'Arvind Shanker Pitre',
#   'Ashok Salvi',
#   'Sagari Radhika Ramdas',
#   'Damodar Acharya',
#   'Vineet Rai',
#   'Gopi Gopalakrishnan',
#   'Deepjyoti Sonu',
#   'Vivek Gilani',
#   'Paul Basil',
#   'Vyjayanthi Sankar',
#   'Heera Lal Sharma',
#   'Rani Bang',
#   'Biplab Ketan Paul',
#   'Mihir Bhatt',
#   'B. Sailakshmi',
#   'Jeanne Devos',
#   'Glory Alexander',
#   'Indrani Malkani',
#   'Ashok Kumar Rau',
#   'Alphonse Jemonie',
#   'Mathew Jose',
#   'Judy Ann Frater',
#   'Rahul Banerjee',
#   'Soma Sen gupta',
#   'Srinivas Chary Vedala',
#   'Sharad Sharma',
#   'Ketan Deshpande',
#   'Seema Prakash',
#   'Kiran Sethi',
#   'Parag Mankeekar',
#   'Devi Prasad Shetty',
#   'Madhavi Tambay',
#   'Laxman Singh',
#   'Lenin Raghuvanshi',
#   'Dr. Kedar Ranjan Banerjee',
#   'Mandira Kumar',
#   'Kousalya Periasamy',
#   'Prasad Rasal',
#   'Suparna Gupta',
#   'Andrew Cross',
#   'Dinesh Kumar',
#   'Anshul Tewari',
#   'Indu Harkrishanlal Capoor',
#   'Vibha Krishnamurthy',
#   'Anuja Gupta',
#   'Tulika Das',
#   'Abhinav Agrawal',
#   'Rohit Baluja',
#   'Vishal Talreja',
#   'Colin Gonsalves',
#   'Kiran Kulkarni',
#   'Lewitt Somarajan',
#   'Aditya Nataraj',
#   'Pratima Joshi',
#   'Sarbani Das Roy',
#   'Muthu Peraman',
#   'Pradip Kumar Sarmah',
#   'C V Madhukar',
#   'Roma Debabrata',
#   'Soumyadeep Datta',
#   'Edith Elliott',
#   'Geeta Ramanujam',
#   'Raghunath Manwar',
#   'Ashok Row Kavi',
#   'Rajat Mitra',
#   'Prema Gopalan',
#   'Sachin Jain',
#   'Suchitra Sheth',
#   'Sikha Roy',
#   'Abhay Shukla',
#   'Raja Menon',
#   'Gangadhar Patil',
#   'Sujay Santra',
#   'Jaya Prakash Rao Polsani',
#   'Nagesh BS',
#   'Satyan Mishra',
#   'Jagadish Pradhan',
#   'Sohini Chakraborty',
#   'Paramita Banerjee',
#   'Govindaiah Krishna Prasad',
#   'Ganesh Pangare',
#   'Prasanta Tripathy',
#   'Milesh Hamlai',
#   'Nalini Nayak',
#   'Vibha Marfatia',
#   'Sanjay Moreshwar Bapat',
#   'Dilip Banerjee',
#   'Ashok Bharti',
#   'Vikram Parchure',
#   'M. Prakasamma',
#   'Roma Malik',
#   'Sachin Chitra',
#   'Emami Murmu',
#   'Bharath Palavalli',
#   'Sampath JM',
#   'Nazma Akter',
#   'Svati Bhogle',
#   'Sonali Ojha',
#   'Ashok Khosla',
#   'Apar Gupta',
#   'Abhay Bang',
#   'Pranshu Singhal',
#   'Yambem Laba',
#   'Sarat Babu Vasireddy',
#   'Sunil Ayrookhuziel Abraham',
#   'Vijay Uttarwar',
#   'Maria Clete',
#   'Monica Kumar',
#   'S.M. Cyril Mooney',
#   'Harish Hande',
#   'Ashwin Mahesh',
#   'Priti Patkar',
#   'Renu Appachu',
#   'Kapilananda Mondal',
#   'Sourirajan Srinivasan',
#   'Milind Ranade',
#   'Hasina Kharbhih',
#   'Leena Joshi',
#   'Ishita Chaudhry',
#   'Arbind Singh',
#   'Rakhee Choudhury',
#   'Dr. Shyamala Nataraj',
#   'Jude Henriques',
#   'Christopher Rego',
#   'Kaushlendra Kumar',
#   'Anup Nair',
#   'Priya Agarwal',
#   'Anjana Batra',
#   'Thenpandian Pandian S',
#   'Sunita Satyarthia',
#   'Suman Sahai',
#   'Amol Goje',
#   'Anand Sunderraman',
#   'Meera K',
#   'Mira Sadgopal',
#   'Neelkanth Mishra',
#   'Will Muir',
#   'Kate Currawalla',
#   'Shivaram Pailoor',
#   'Vandana Gopikumar',
#   'Anant Sharma',
#   'Shyamala Nataraj',
#   'Zeena Johar',
#   'Rana Sengupta',
#   'Tejbir Singh',
#   'Armida Fernandez',
#   'Piyush Tewari',
#   'Anup Akkihal',
#   'Mangal Singh',
#   'Sriram Kuchimanchi',
#   'Nagamalai Muthu Velayutham',
#   'Arjun Venkatraman',
#   'Sugandha Sukrutaraj',
#   'Gautam Bharadwaj',
#   'Rupen Das',
#   'Anu Wakhlu',
#   'Asim Suhas Sarode',
#   'Shailabh Kumar',
#   'Hanumappa Sudarshan',
#   'Swapnil Chaturvedi',
#   'Anil Singh',
#   'Sashikala Ananth',
#   'Latha Anantha',
#   'Samina Bano',
#   'Aditya Patnaik',
#   'Shivani Siroya',
#   'Ela Bhatt',
#   'Rajeev Khedkar',
#   'GNS Reddy',
#   'Abhishek Ray',
#   'Jagdish Pradhan',
#   'Ajit Singh',
#   'Nirupama Sekhri',
#   'Maxine Berntsen',
#   'Kallol Ghosh',
#   'Santosh Choubey',
#   'Dr. Gokulan Bhargavi Gopinath',
#   'Babloo Loitongbam',
#   'Asim Sarode',
#   'Dr. Thara Srinivasan',
#   'Manu gupta',
#   'Gananath S N',
#   'Jithin Nedumala',
#   'Pralhad Malvadkar',
#   'Vijay Mahajan',
#   'Ved Arya',
#   'Manoj Bhatt',
#   'Prasanna Shirol',
#   'Stanislaus Jebamalai',
#   'Kalyan Paul',
#   'Gangadharan Gopinathan Geethalayam',
#   'Nandini Mundkur'],
#  441)

# %%
for fellow in fellows:
    print([fellow,"is a fellow at","Ashoka"])
    edgesheet.insert_rows(edgesheet.rows,values=[fellow,"is a fellow at","Ashoka"], inherit=True)
# Out:
# ['Deep Purokayastha', 'is a fellow at', 'Ashoka']
# ['Flavia Agnes', 'is a fellow at', 'Ashoka']
# ['Pranjal Baruah', 'is a fellow at', 'Ashoka']
# ['Akkai Padmashali', 'is a fellow at', 'Ashoka']
# ['Rita Banerji', 'is a fellow at', 'Ashoka']
# ['Jaya Prakash Rao', 'is a fellow at', 'Ashoka']
# ['Amitav Virmani', 'is a fellow at', 'Ashoka']
# ['Vibha Gupta', 'is a fellow at', 'Ashoka']
# ['Pranil Naik', 'is a fellow at', 'Ashoka']
# ['Akshay Saxena', 'is a fellow at', 'Ashoka']
# ['Sharath Jeevan', 'is a fellow at', 'Ashoka']
# ['Pankaj Jain', 'is a fellow at', 'Ashoka']
# ['Pandurang Ganapati Hegde', 'is a fellow at', 'Ashoka']
# ['Solomon Jaya Prakash', 'is a fellow at', 'Ashoka']
# ['Haushala Prasad Shriram Mishra', 'is a fellow at', 'Ashoka']
# ['Sonam Wangchuk', 'is a fellow at', 'Ashoka']
# ['Hilmi Quraishi', 'is a fellow at', 'Ashoka']
# ['Kailash Satyarthi', 'is a fellow at', 'Ashoka']
# ['Jessica Mayberry', 'is a fellow at', 'Ashoka']
# ['Sanvardeep Oberoi', 'is a fellow at', 'Ashoka']
# ['Isidore Phillips', 'is a fellow at', 'Ashoka']
# ['Ashwin Naik', 'is a fellow at', 'Ashoka']
# ['Anjali Bharadwaj', 'is a fellow at', 'Ashoka']
# ['Sunitha Krishnan', 'is a fellow at', 'Ashoka']
# ['Suprabha Seshan', 'is a fellow at', 'Ashoka']
# ['Naginbhai Shah', 'is a fellow at', 'Ashoka']
# ['S.L.N Swamy', 'is a fellow at', 'Ashoka']
# ['AR Palaniswamy', 'is a fellow at', 'Ashoka']
# ['KA Thomas', 'is a fellow at', 'Ashoka']
# ['Pravin Khandpasole', 'is a fellow at', 'Ashoka']
# ['Chhanda Bose', 'is a fellow at', 'Ashoka']
# ['Ramya Venkataraman', 'is a fellow at', 'Ashoka']
# ['Anil Patil', 'is a fellow at', 'Ashoka']
# ['S. Bandopadhyay', 'is a fellow at', 'Ashoka']
# ['Vijay Singh Aditya', 'is a fellow at', 'Ashoka']
# ['Sudhirendar Sharma', 'is a fellow at', 'Ashoka']
# ['Rao Padmanabha Yerravalli', 'is a fellow at', 'Ashoka']
# ['Dr. Purobie Bose', 'is a fellow at', 'Ashoka']
# ['Rashneh Pardiwala', 'is a fellow at', 'Ashoka']
# ['Parul Sheth', 'is a fellow at', 'Ashoka']
# ['Parashurama Mynakanahalli Lingegowda', 'is a fellow at', 'Ashoka']
# ['Nirmala Srinivasan', 'is a fellow at', 'Ashoka']
# ['Sujit Sinha', 'is a fellow at', 'Ashoka']
# ['Shanti Raghavan', 'is a fellow at', 'Ashoka']
# ['Ravi Aggarwal', 'is a fellow at', 'Ashoka']
# ['Hanif Lakdawala', 'is a fellow at', 'Ashoka']
# ['Akanksha Hazari', 'is a fellow at', 'Ashoka']
# ['Sushobha Barve', 'is a fellow at', 'Ashoka']
# ['Ritwick Dutta', 'is a fellow at', 'Ashoka']
# ['Romulus Earl Whitaker', 'is a fellow at', 'Ashoka']
# ['Balaji Sampath', 'is a fellow at', 'Ashoka']
# ['Anindita Majumdar', 'is a fellow at', 'Ashoka']
# ['Lalitha Raghuram', 'is a fellow at', 'Ashoka']
# ['John J', 'is a fellow at', 'Ashoka']
# ['Shilpi Kapoor', 'is a fellow at', 'Ashoka']
# ['Sunita Bagal', 'is a fellow at', 'Ashoka']
# ['Shashank Kumar', 'is a fellow at', 'Ashoka']
# ['Madhavi Kuckreja', 'is a fellow at', 'Ashoka']
# ['Maitreyee Chatterjee', 'is a fellow at', 'Ashoka']
# ['Aman Singh', 'is a fellow at', 'Ashoka']
# ['Monish Anand', 'is a fellow at', 'Ashoka']
# ['Kavita Anand', 'is a fellow at', 'Ashoka']
# ['Umesh Malhotra', 'is a fellow at', 'Ashoka']
# ['Raju Purohit', 'is a fellow at', 'Ashoka']
# ['Shakil Ahmed', 'is a fellow at', 'Ashoka']
# ['Anita Ahuja', 'is a fellow at', 'Ashoka']
# ['Hardika Shah', 'is a fellow at', 'Ashoka']
# ['Partap chauhan', 'is a fellow at', 'Ashoka']
# ['Vivek Pandit', 'is a fellow at', 'Ashoka']
# ['Sheilu Srinivasan', 'is a fellow at', 'Ashoka']
# ['Sanjay Bapat', 'is a fellow at', 'Ashoka']
# ['Bhargavi Davar', 'is a fellow at', 'Ashoka']
# ['Susheela Bhan', 'is a fellow at', 'Ashoka']
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pygsheets/sheet.py in _execute_requests(self, request)
#     350         try:
# --> 351             response = request.execute(num_retries=self.retries)
#     352         except HttpError as error:
#
# /usr/local/lib/python3.8/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# /usr/local/lib/python3.8/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     906         if resp.status >= 300:
# --> 907             raise HttpError(resp, content, uri=self.uri)
#     908         return self.postproc(resp, content)
#
# HttpError: <HttpError 429 when requesting https://sheets.googleapis.com/v4/spreadsheets/1CihUjjhCueFBGB74d1MZnIx-SpJxQCWuGE8IKVP8B6k:batchUpdate?fields=%2A&alt=json returned "Quota exceeded for quota group 'WriteGroup' and limit 'Write requests per user per 100 seconds' of service 'sheets.googleapis.com' for consumer 'project_number:852474510412'.". Details: "[{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Google developer console API key', 'url': 'https://console.developers.google.com/project/852474510412/apiui/credential'}]}]">
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-5b5f701970e8> in <module>
#       1 for fellow in fellows:
#       2     print([fellow,"is a fellow at","Ashoka"])
# ----> 3     edgesheet.insert_rows(edgesheet.rows,values=[fellow,"is a fellow at","Ashoka"], inherit=True)
#
# /usr/local/lib/python3.8/dist-packages/pygsheets/worksheet.py in insert_rows(self, row, number, values, inherit)
#     801                                        'range': {'sheetId': self.id, 'dimension': 'ROWS',
#     802                                                  'endIndex': (row+number), 'startIndex': row}}}
# --> 803         self.client.sheet.batch_update(self.spreadsheet.id, request)
#     804         self.jsonSheet['properties']['gridProperties']['rowCount'] = self.rows + number
#     805         if values:
#
# /usr/local/lib/python3.8/dist-packages/pygsheets/sheet.py in batch_update(self, spreadsheet_id, requests, **kwargs)
#      92         request = self.service.spreadsheets().batchUpdate(spreadsheetId=spreadsheet_id,
#      93                                                           body=body, **kwargs)
# ---> 94         return self._execute_requests(request)
#      95
#      96     def create(self, title, template=None, **kwargs):
#
# /usr/local/lib/python3.8/dist-packages/pygsheets/sheet.py in _execute_requests(self, request)
#     352         except HttpError as error:
#     353             if error.resp['status'] == '429':
# --> 354                 time.sleep(self.seconds_per_quota)  # TODO use asyncio
#     355                 response = request.execute(num_retries=self.retries)
#     356             else:
#
# KeyboardInterrupt:

# %%
fellowdfs=[]
for sheet in ashokasheet.worksheets():
    sheetdf=sheet.get_as_df()
    if "Org" not in sheetdf.columns:
        sheetdf['Org']=numpy.nan
    fellowdfs.append(sheetdf[['Full Name','Org']])

# %%
felloworgs=pandas.concat(fellowdfs).drop_duplicates(subset=["Full Name"]).fillna("None")

# %%
for name in felloworgs['Full Name']:
    print([fellow,"is a fellow at","Ashoka"],1)
    org=felloworgs[felloworgs['Full Name']==name]['Org'].values[0].replace("\n","").lstrip().rstrip()
    edgesheet.insert_rows(edgesheet.rows,values=[name,"is a fellow at","Ashoka",1], inherit=True)
    if org != "" and org != " ":
        print([name,"is a key person at", org,1])
        edgesheet.insert_rows(edgesheet.rows,values=[name,"is a key person at", org,1], inherit=True)
    xetrapal.karma.wait(waittime="short")
# Out:
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Deepjyoti Sonu', 'is a key person at', 'Farm2Food', 1]
# 2020-08-10 17:46:48 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 2 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Emami Murmu', 'is a key person at', 'Pragatisheel Mahila Sabha', 1]
# 2020-08-10 17:46:53 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 2 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Sneh Kumar', 'is a key person at', 'ADITI', 1]
# 2020-08-10 17:46:57 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 9 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Yambem Laba', 'is a key person at', 'Manipur Mountaineering and Trekking Association', 1]
# 2020-08-10 17:47:08 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 8 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Hasina Kharbhih', 'is a key person at', 'Impulse Social Enterprises', 1]
# 2020-08-10 17:47:18 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 0 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Krishna Chandra Mishra ', 'is a key person at', 'E-Kutir', 1]
# 2020-08-10 17:47:20 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Dilip Banerjee ', 'is a key person at', 'Individual Dilip Banerjee', 1]
# 2020-08-10 17:47:27 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 9 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Sarbani Das Roy ', 'is a key person at', 'Iswar Sankalpa', 1]
# 2020-08-10 17:47:39 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 4 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Sikha Roy', 'is a key person at', 'Srreoshi', 1]
# 2020-08-10 17:47:46 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 8 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Sujay Santra ', 'is a key person at', 'iKure Techsoft (P) Ltd', 1]
# 2020-08-10 17:47:56 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 0 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['KA Thomas ', 'is a key person at', 'Institution for Culture And Rural Development (I-CARD)', 1]
# 2020-08-10 17:47:58 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Pranjal Baruah', 'is a key person at', 'Mushroom Development Foundation', 1]
# 2020-08-10 17:48:06 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Ravindranath', 'is a key person at', 'River Basin Friends', 1]
# 2020-08-10 17:48:12 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Soumyadeep Datta', 'is a key person at', "Nature's Beckon", 1]
# 2020-08-10 17:48:17 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Kaushlendra Kumar', 'is a key person at', 'Kaushalya Foundation', 1]
# 2020-08-10 17:48:25 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Shashank Kumar', 'is a key person at', 'Farms and Farmers (FnF) Foundation', 1]
# 2020-08-10 17:48:33 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Prasanta Tripathy', 'is a key person at', 'Ekjut', 1]
# 2020-08-10 17:48:53 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 4 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Babloo Loitongbam ', 'is a key person at', 'Human Rights Alert', 1]
# 2020-08-10 17:49:02 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 2 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Dr Bibhu Kalyan Mohanty', 'is a key person at', 'Sambandh', 1]
# 2020-08-10 17:49:07 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 0 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Jagadish Pradhan ', 'is a key person at', 'Sahabhagi Vikas Abhiyan', 1]
# 2020-08-10 17:49:10 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Sundara Narayana Patro', 'is a key person at', 'Odisha Environmental Society', 1]
# 2020-08-10 17:49:15 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 7 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Aditya Patnaik', 'is a key person at', 'Antyodaya Chetna Mandal', 1]
# 2020-08-10 17:49:26 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 4 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Abhijit Bardhan ', 'is a key person at', 'Science Communicators Forum', 1]
# 2020-08-10 17:49:34 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 0 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Amlan Kusum Ganguly ', 'is a key person at', 'Prayasam', 1]
# 2020-08-10 17:49:38 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Anindita Majumdar', 'is a key person at', 'EquiDiversity Foundation', 1]
# 2020-08-10 17:49:45 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 7 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Anuradha Kapoor ', 'is a key person at', 'Swayam', 1]
# 2020-08-10 17:49:57 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Aparna Banerjee', 'is a key person at', 'Project Sukanya', 1]
# 2020-08-10 17:50:06 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 4 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Chandra Shekhar Ghosh ', 'is a key person at', 'Bandhan', 1]
# 2020-08-10 17:50:13 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 2 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Deep Purokayastha ', 'is a key person at', 'PRAAJAK', 1]
# 2020-08-10 17:50:20 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 7 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Dr. Kedar Ranjan Banerjee ', 'is a key person at', 'NIBS Kolkata', 1]
# 2020-08-10 17:50:30 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 7 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Dr. Purobie Bose ', 'is a key person at', 'Society For Remedial Education Assessment Counselling Handicapped', 1]
# 2020-08-10 17:50:41 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 4 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Indrani Chakravarty', 'is a key person at', 'Calcutta Metropolitan Institute of Gentrology', 1]
# 2020-08-10 17:50:48 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Kallol Ghosh ', 'is a key person at', 'Organisation For Friends, Energy and Resources (OFFER)', 1]
# 2020-08-10 17:51:13 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 4 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Krishna Roy ', 'is a key person at', 'Nari Nirjatan Pratirodh Mancha', 1]
# 2020-08-10 17:51:24 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 9 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Mina Das', 'is a key person at', 'Nishtha', 1]
# 2020-08-10 17:51:36 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 1 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Raja Menon', 'is a key person at', 'Jeevika Development Society', 1]
# 2020-08-10 17:51:41 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 1 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Ratnaboli Ray ', 'is a key person at', 'Anjali Mental Health Rights Organisation', 1]
# 2020-08-10 17:51:48 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['S.M. Cyril Mooney', 'is a key person at', 'Loreto House Sealdah', 1]
# 2020-08-10 17:51:59 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 8 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['S. Bandopadhyay', 'is a key person at', 'Navadiganta', 1]
# 2020-08-10 17:52:11 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 1 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Sohini Chakraborty', 'is a key person at', 'Kolkata Sanved', 1]
# 2020-08-10 17:52:16 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 9 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Tulika Das ', 'is a key person at', 'Sanchar', 1]
# 2020-08-10 17:52:28 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Kamal Kanti Banik', 'is a key person at', 'Dishari', 1]
# 2020-08-10 17:52:37 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 2 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Chingmak Sipong Chang', 'is a key person at', 'Eleutheros Christian Society', 1]
# 2020-08-10 17:52:42 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['John J', 'is a key person at', 'Grassroot Tea Corporation', 1]
# 2020-08-10 17:52:51 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Paramita Banerjee', 'is a key person at', 'Individual Paramita Banerjee', 1]
# 2020-08-10 17:52:57 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 2 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Dinesh Kumar Mishra', 'is a key person at', 'Barh Mukti Abhiyan (Freedom from Floods Campaign)', 1]
# 2020-08-10 17:53:01 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Mohammad Nooruddin Amin', 'is a key person at', 'Adhikar', 1]
# 2020-08-10 17:53:09 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Prabhat Kumar', 'is a key person at', 'Kisan Vikash Trust', 1]
# 2020-08-10 17:53:17 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Chhanda Bose', 'is a key person at', 'Individual India', 1]
# 2020-08-10 17:53:24 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 4 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Maitreyee Chatterjee', 'is a key person at', 'Nari Nirjatan Partirodh Mancha', 1]
# 2020-08-10 17:53:31 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Ashru Mandal', 'is a key person at', 'Ashru Mandal Individual', 1]
# 2020-08-10 17:53:36 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Jude Henriques', 'is a key person at', 'Individual India', 1]
# 2020-08-10 17:53:41 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Soma Sen gupta', 'is a key person at', 'Sanhita', 1]
# 2020-08-10 17:53:49 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 0 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# 2020-08-10 17:53:50 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Ahsan Rony', 'is a key person at', 'Green savers association', 1]
# 2020-08-10 17:53:58 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 8 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Nazma Akter', 'is a key person at', 'Awaj Foundation', 1]
# 2020-08-10 17:54:08 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Albert Mollah', 'is a key person at', 'Access Bangladesh', 1]
# 2020-08-10 17:54:14 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Choitresh Kumar Ganguly', 'is a key person at', 'Timbaktu Collective', 1]
# 2020-08-10 17:54:21 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 0 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Dinesh Kumar', 'is a key person at', 'Earth 360', 1]
# 2020-08-10 17:54:24 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 9 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Akkai Padmashali', 'is a key person at', 'Ondede', 1]
# 2020-08-10 17:54:36 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Alphonse Jemonie', 'is a key person at', 'Goodwill International Association', 1]
# 2020-08-10 17:54:41 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Anselm Rosario', 'is a key person at', 'Mythri Sarva Seva Samithi', 1]
# 2020-08-10 17:54:47 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Anup Akkihal', 'is a key person at', 'Logistimo', 1]
# 2020-08-10 17:55:06 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 2 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Ashok Kumar Rau', 'is a key person at', 'Freedom Foundation', 1]
# 2020-08-10 17:55:10 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Ashwin Naik', 'is a key person at', 'Vaatsalya', 1]
# 2020-08-10 17:55:19 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Ayyappa Mahadevappa Masagi', 'is a key person at', 'Water literacy foundation and rainwater concepts ind pvt ltd', 1]
# 2020-08-10 17:55:26 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['C V Madhukar', 'is a key person at', 'PRS Legislative Research', 1]
# 2020-08-10 17:55:35 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 4 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Christopher Rego', 'is a key person at', 'The Sunbird Trust', 1]
# 2020-08-10 17:55:42 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Damodar Acharya', 'is a key person at', 'The Concerned for Working Children', 1]
# 2020-08-10 17:55:49 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 8 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Devi Prasad Shetty', 'is a key person at', 'Narayana Hrudayalaya', 1]
# 2020-08-10 17:56:00 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 4 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Edith Elliott', 'is a key person at', 'Noora Health', 1]
# 2020-08-10 17:56:06 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Anup Nair', 'is a key person at', 'LEDs(Local Economic Development Society)', 1]
# 2020-08-10 17:56:11 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['AR Palaniswamy', 'is a key person at', 'Society for Educational and Economic Development(founded 1981)', 1]
# 2020-08-10 17:56:17 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 9 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['B. Sailakshmi', 'is a key person at', 'Ekam', 1]
# 2020-08-10 17:56:28 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 8 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Balaji Sampath', 'is a key person at', 'Aid India', 1]
# 2020-08-10 17:56:38 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Elango Rangaswamy ', 'is a key person at', 'Trust for Village Self Governance', 1]
# 2020-08-10 17:56:47 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 8 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Errabelli Madan Mohan Rao', 'is a key person at', 'Rural Telecom Foundation', 1]
# 2020-08-10 17:56:58 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Gananath S N', 'is a key person at', 'Suvidya', 1]
# 2020-08-10 17:57:05 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 2 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Gangadhar Patil', 'is a key person at', '101 Reporters', 1]
# 2020-08-10 17:57:09 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Gangadharan Gopinathan Geethalayam', 'is a key person at', 'LSPSS ( Lok Swasthya Parampara Samvardhan Samiti )', 1]
# 2020-08-10 17:57:14 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 4 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Geeta Ramanujam', 'is a key person at', '"Kathalaya Academy of Storytelling"', 1]
# 2020-08-10 17:57:22 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 1 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# 2020-08-10 17:57:24 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 4 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Gita Ramaswamy', 'is a key person at', 'Ibrahimpatnam Vyavasaya Coolie Sangham', 1]
# 2020-08-10 17:57:31 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Glory Alexander', 'is a key person at', 'Asha Foundation', 1]
# 2020-08-10 17:57:38 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 9 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['GNS Reddy', 'is a key person at', 'Akshayakalpa', 1]
# 2020-08-10 17:57:49 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Dr. Gokulan Bhargavi Gopinath', 'is a key person at', 'Sudarshanam Netra Chikitsalayam', 1]
# 2020-08-10 17:57:55 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 7 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Govindaiah Krishna Prasad', 'is a key person at', 'Sahadja Samrudha', 1]
# 2020-08-10 17:58:04 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Hanumappa Sudarshan', 'is a key person at', 'Vivekananda Girijana Kalyana Kendra (VGKK) & Karuna Trust', 1]
# 2020-08-10 17:58:09 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Hardika Shah', 'is a key person at', 'Kinara Capital', 1]
# 2020-08-10 17:58:15 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 8 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Harish Hande', 'is a key person at', 'SELCO', 1]
# 2020-08-10 17:58:25 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Harry Andrews', 'is a key person at', 'Centre for Herpetology', 1]
# 2020-08-10 17:58:34 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Isidore Phillips', 'is a key person at', 'Divya Disha', 1]
# 2020-08-10 17:58:42 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Janardhana Gungurumale', 'is a key person at', 'SOSAD', 1]
# 2020-08-10 17:58:47 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 1 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Jasmeen Patheja', 'is a key person at', 'Blank Noise', 1]
# 2020-08-10 17:58:50 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 3 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Jayaprakash Rao Polsani', 'is a key person at', 'NA', 1]
# 2020-08-10 17:58:56 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Jithin Nedumala', 'is a key person at', 'Make a Difference', 1]
# 2020-08-10 17:59:03 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 6 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Kavitha Krishnamoorthy', 'is a key person at', 'Kilikili', 1]
# 2020-08-10 17:59:11 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 8 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Kousalya Periasamy', 'is a key person at', 'Positive Women Network PWN+', 1]
# 2020-08-10 17:59:22 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 0 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Kuldeep Dantewadia', 'is a key person at', 'Reap Benefit', 1]
# 2020-08-10 17:59:24 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 1 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Lalitha Raghuram', 'is a key person at', 'Mohan Foundation', 1]
# 2020-08-10 17:59:27 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 0 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Latha Anantha', 'is a key person at', 'River Research Center', 1]
# 2020-08-10 17:59:29 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 2 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['M. Prakasamma', 'is a key person at', 'ANSWERS', 1]
# 2020-08-10 17:59:33 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 7 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Mananjeri Basu Nirmal', 'is a key person at', 'ExNoRa International', 1]
# 2020-08-10 17:59:43 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
# ['Susheela Bhan', 'is a fellow at', 'Ashoka'] 1
# ['Mandira Kumar', 'is a key person at', 'Sutradhar Educational Resource Centre', 1]
# 2020-08-10 17:59:51 Xpal-Sutradhar-MainThread-[wait] INFO : Waiting for a short duration : 5 seconds
